# %%
from urllib.parse import quote_plus

import pandas as pd
from sqlalchemy import create_engine

username = quote_plus("root")
password = quote_plus("1234567890")
server = "host.docker.internal:3307"
db_name = "TESTDB"

conn = create_engine(
    f"mysql+pymysql://{username}:{password}@{server}/{db_name}?autocommit=true",
).connect()

# %%
sql = "select * from Staff"
df = pd.read_sql(sql, conn)
df
# Out:
#    index   ID   Name DeptId  Age Gender  Salary            recordDt
# 0      0  001   Mike    002   45      M   60000 2020-10-13 21:41:49
# 1      1  002   Judy    002   30      F   48000 2020-10-13 21:41:49
# 2      2  003  Allen    001   22      M   50000 2020-10-13 21:41:49
# 3      3  004    Tom    002   47      M   47000 2020-10-13 21:41:49
# 4      4  005   Jack    003   36      M   52000 2020-10-13 21:41:49
# 5      5  006   Abby    002   24      F   45000 2020-10-13 21:41:49
# 6      6  007  Trump    001   80      M   80000 2020-10-13 21:41:49
# 7      7  008  Marry    003   29      F   87000 2020-10-13 21:41:49

# %%
df.to_sql("Staff", conn, if_exists="replace", index=False)
# Out:
# 8

# %%
df = df.drop("index", axis=1)
df
# Out:
#     ID   Name DeptId  Age Gender  Salary            recordDt
# 0  001   Mike    002   45      M   60000 2020-10-13 21:41:49
# 1  002   Judy    002   30      F   48000 2020-10-13 21:41:49
# 2  003  Allen    001   22      M   50000 2020-10-13 21:41:49
# 3  004    Tom    002   47      M   47000 2020-10-13 21:41:49
# 4  005   Jack    003   36      M   52000 2020-10-13 21:41:49
# 5  006   Abby    002   24      F   45000 2020-10-13 21:41:49
# 6  007  Trump    001   80      M   80000 2020-10-13 21:41:49
# 7  008  Marry    003   29      F   87000 2020-10-13 21:41:49

# %%
df.to_sql("Staff", conn, if_exists="replace", index=False)

# %%
sample_data = {
    "ID": ["001", "002", "003", "004", "005", "006", "007", "008"],
    "Name": ["Mike", "Judy", "Allen", "Tom", "Jack", "Abby", "Trump", "Marry"],
    "DeptId": ["002", "002", "001", "002", "003", "002", "001", "003"],
    "Age": [45, 30, 22, 47, 36, 24, 80, 29],
    "Gender": ["M", "F", "M", "M", "M", "F", "M", "F"],
    "Salary": [60000, 48000, 50000, 47000, 52000, 45000, 80000, 87000],
    "recordDt": [
        "2020-10-13 21:41:49", "2020-10-13 21:41:49", "2020-10-13 21:41:49",
        "2020-10-13 21:41:49", "2020-10-13 21:41:49", "2020-10-13 21:41:49",
        "2020-10-13 21:41:49", "2020-10-13 21:41:49"
    ]
}

sample_df = pd.DataFrame(sample_data)
sample_df
# Out:
#     ID   Name DeptId  Age Gender  Salary             recordDt
# 0  001   Mike    002   45      M   60000  2020-10-13 21:41:49
# 1  002   Judy    002   30      F   48000  2020-10-13 21:41:49
# 2  003  Allen    001   22      M   50000  2020-10-13 21:41:49
# 3  004    Tom    002   47      M   47000  2020-10-13 21:41:49
# 4  005   Jack    003   36      M   52000  2020-10-13 21:41:49
# 5  006   Abby    002   24      F   45000  2020-10-13 21:41:49
# 6  007  Trump    001   80      M   80000  2020-10-13 21:41:49
# 7  008  Marry    003   29      F   87000  2020-10-13 21:41:49

# %%
sample_df.to_sql("test_staff", conn, index=False, if_exists="append")
# Out:
# 8

# %%
sample_df.to_sql("test_staff_2", conn, index=False, if_exists="append")
# Out:
# 8

# %%
sample_df.to_sql("Staff", conn, index=False, if_exists="append")
# Out:
# 8

# %%
sample_df.to_sql("Staff", conn, index=False, if_exists="append")
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/engine/base.py:1933, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1932     if not evt_handled:
# -> 1933         self.dialect.do_executemany(
#    1934             cursor,
#    1935             str_statement,
#    1936             effective_parameters,
#    1937             context,
#    1938         )
#    1939 elif not effective_parameters and context.no_parameters:
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:172, in MySQLDialect_mysqldb.do_executemany(self, cursor, statement, parameters, context)
#     171 def do_executemany(self, cursor, statement, parameters, context=None):
# --> 172     rowcount = cursor.executemany(statement, parameters)
#     173     if context is not None:
#
# ...

# %%
conn.close()

# %%
with create_engine(
    f"mysql+pymysql://{username}:{password}@{server}/{db_name}?autocommit=true",
).connect() as conn:
    df = pd.read_sql("select * from Staff", conn)

# %%
df
# Out:
#     ID   Name DeptId  Age Gender  Salary            recordDt
# 0  001   Mike    002   45      M   60000 2020-10-13 21:41:49
# 1  002   Judy    002   30      F   48000 2020-10-13 21:41:49
# 2  003  Allen    001   22      M   50000 2020-10-13 21:41:49
# 3  004    Tom    002   47      M   47000 2020-10-13 21:41:49
# 4  005   Jack    003   36      M   52000 2020-10-13 21:41:49
# 5  006   Abby    002   24      F   45000 2020-10-13 21:41:49
# 6  007  Trump    001   80      M   80000 2020-10-13 21:41:49
# 7  008  Marry    003   29      F   87000 2020-10-13 21:41:49
